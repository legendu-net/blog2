# %% [markdown]
# ---
# title: Encoding and Decoding Base64 String in Python
# created: 2021-07-29 19:49:07
# date: 2026-04-13 23:14:15.105264
# authors:
#   - bendu
# label: encoding-and-decoding-base64-string-in-python
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - Python
#   - base64
#   - string
#   - encode
#   - decode
# ---

# %%
import base64

# %%
text = base64.b64encode("how are you".encode()).decode()
text

# %%
base64.b64decode(text).decode()

# %% [markdown]
# ## References
#
# [base64 — Base16, Base32, Base64, Base85 Data Encodings](https://docs.python.org/3/library/base64.html)

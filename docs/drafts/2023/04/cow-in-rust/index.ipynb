# %% [markdown]
# ---
# title: Cow in Rust
# created: 2023-04-14 12:19:22
# date: 2023-04-17 14:36:36
# authors:
# - bendu
# label: cow-in-rust
# license: CC-BY-4.0
# tags:
# - Computer Science
# - programming
# - Rust
# - Cow
# - copy on write
# - clone on write
#
# ---
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## References
#
# - [Enum std::borrow::Cow](https://doc.rust-lang.org/std/borrow/enum.Cow.html)
#
# - [Using Cow in Rust for efficient memory utilization](https://blog.logrocket.com/using-cow-rust-efficient-memory-utilization/)

# %% [markdown]
# ---
# title: Tips on the jupyter-ai Extension
# created: 2023-12-31 21:32:45
# date: 2026-04-13 23:15:28.443616
# authors:
#   - bendu
# label: tips-on-the-jupyter-ai-extension
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
# %load_ext jupyter_ai

# %%
# %ai list

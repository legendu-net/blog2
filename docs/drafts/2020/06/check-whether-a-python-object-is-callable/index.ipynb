# %% [markdown]
# ---
# title: Check Whether a Python Object Is Callable
# created: 2020-06-20 12:38:55
# date: 2020-06-20 12:38:55
# authors:
# - bendu
# label: check-whether-a-python-object-is-callable
# license: CC-BY-4.0
# tags:
# - Computer Science
# - Python
# - callable
# - function
# - object
#
# ---
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
f = lambda x: 1

# %%
callable(f)
# Out:
# True

# %%
def fun():
    return 1

# %%
callable(fun)
# Out:
# True

# %%
x = 1

# %%
callable(x)
# Out:
# False

# %% [markdown]
# ---
# title: Calculate Hash of a Directory in Python
# created: 2020-08-04 08:47:43
# date: 2026-04-13 23:15:28.971891
# authors:
#   - bendu
# label: calculate-hash-of-a-directory-in-python
# license: CC-BY-4.0
# tags:
#   - computer science
#   - Python
#   - directory
#   - dir
#   - hash
#   - md5sum
#   - recursive
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Comments
#
# https://github.com/andhus/dirhash-python
# is prefered to
# https://github.com/cakepietoast/checksumdir
# .

# %% [markdown]
# ## References
#
# https://github.com/andhus/dirhash-python
#
# https://github.com/cakepietoast/checksumdir

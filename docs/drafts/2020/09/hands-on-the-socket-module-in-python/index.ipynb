# %% [markdown]
# ---
# title: Hands on the Socket Module in Python
# created: 2020-09-05 13:15:27
# date: 2026-04-13 23:15:28.961254
# authors:
#   - bendu
# label: hands-on-the-socket-module-in-python
# license: CC-BY-4.0
# tags:
#   - computer science
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import socket

# %%
hostname = socket.gethostname()

# %%
socket.gethostbyname(hostname)
# Out:
# '172.17.0.3'

# %%
[m for m in dir(socket) if "host" in m]
# Out:
# ['gethostbyaddr',
#  'gethostbyname',
#  'gethostbyname_ex',
#  'gethostname',
#  'sethostname']

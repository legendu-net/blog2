# %% [markdown]
# ---
# title: Get the Number of Cores in macOS
# created: 2020-04-16 14:41:04
# date: 2020-04-16 14:41:04
# authors:
# - bendu
# label: get-the-number-of-cores-in-macos
# license: CC-BY-4.0
# tags:
# - Computer Science
# - number of cores
# - macOS
#
# ---
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Using Shell Command

# %%
sysctl hw.physicalcpu hw.logicalcpu

# %% [markdown]
# ## Using Python

# %%
import os

os.cpu_count()
# Out:
# 16

# %%
import multiprocessing as mp

mp.cpu_count()
# Out:
# 16

# %% [markdown]
# ## References
#
# https://stackoverflow.com/questions/1715580/how-to-discover-number-of-logical-cores-on-mac-os-x

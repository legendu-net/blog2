# %% [markdown]
# ---
# title: Parse Xml in Python
# created: 2020-10-07 15:43:47
# date: 2020-10-07 15:43:47
# authors:
# - bendu
# label: parse-xml-in-python
# license: CC-BY-4.0
# tags:
# - Computer Science
# - Python
# - XML
# - HTML
# - XHTML
# - parse
# - ElementTree
# - HTMLParser
# - BeautifulSoup
# - Beautiful Soup
#
# ---
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# xml.etree.ElementTree
#
# from html.parser import HTMLParser
#
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# https://github.com/lxml/lxml
#
# `xml.etree.ElementTree` is for parsing strict XML text.
# Do NOT use `xml.etree.ElementTree` to parse HTML string.

// %% [markdown]
// ---
// title: Gophernotes Is a Golang Kernel for JupyterLab
// created: 2022-07-21 00:49:04
// date: 2026-04-13 23:15:28.549331
// authors:
//   - bendu
// label: gophernotes-is-a-golang-kernel-for-jupyterlab
// license: CC-BY-4.0
// tags:
//   - computer science
//   - programming
//   - Golang
//   - Gophernotes
//   - Jupyter
//   - JupyterLab
//   - kernel
// ---
//
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %% [markdown]
// [Gophernotes - Special Commands](https://github.com/gopherdata/gophernotes#special-commands)

// %%
$ls
// Out:
// gophernotes-is-a-golang-kernel-for-jupyterlab.ipynb

// %% [markdown]
// ## References
//
// [Gophernotes @ GitHub](https://github.com/gopherdata/gophernotes)

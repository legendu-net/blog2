# %% [markdown]
# ---
# title: Set in Golang
# created: 2022-07-13 21:45:03
# date: 2026-04-14 19:32:05.627087
# authors:
#   - bendu
# label: set-in-golang
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - golang
#   - set
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
# ## Tips and Traps
#
# Golang does NOT have sets natively.
# [github.com/deckarep/golang-set](https://pkg.go.dev/github.com/deckarep/golang-set)
# is a popular 3rd-party set implementation.

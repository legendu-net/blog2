// %% [markdown]
// ---
// title: Integers in Golang
// created: 2022-07-05 17:48:33
// date: 2022-07-05 17:48:33
// authors:
// - bendu
// label: integers-in-golang
// license: CC-BY-4.0
// tags:
// - Computer Science
// - programming
//
// ---
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %%
import "math"
import "strconv"

// %%
var f float64 = 3.2
var v uint = uint(f)
v
// Out:
// 3

// %%
uint(f)
// Out:
// 3

// %%
uint(3.2)
// Out:
// untyped constant {float64 16/5} overflows <uint>

// %%
strconv.Itoa(3)
// Out:
// 3

// %%
math.Max(1, 2)
// Out:
// 2

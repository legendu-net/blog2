# %% [markdown]
# ---
# title: Count Ones in the Binary Represeantion of Integers
# created: 2022-05-16 09:52:10
# date: 2026-04-13 23:15:28.638071
# authors:
#   - bendu
# label: count-ones-in-the-binary-represeantion-of-integers
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - count
#   - bits
#   - ones
#   - Python
#   - Rust
#   - Hamming weight
#   - LeetCode
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
https://leetcode.com/problems/number-of-1-bits/

# %%
class Solution:
    def hammingWeight(self, n: int) -> int:
        num_ones = 0
        while n > 0:
            num_ones += 1
            n &= n - 1
        return num_ones

# %% [markdown]
# Notice that there's a built-in method
# [int.bit_count](https://docs.python.org/3.10/library/stdtypes.html#int.bit_count)
# to do this in Python 3.10+.
# Unsigned integer types in Rust also has a method named
# [count_ones](https://doc.rust-lang.org/std/primitive.u8.html#method.count_ones)
# to do this.

# %% [markdown]
# ## References
#
# https://leetcode.com/problems/number-of-1-bits/

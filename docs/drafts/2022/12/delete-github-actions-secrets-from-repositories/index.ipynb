# %% [markdown]
# ---
# title: Delete GitHub Actions Secrets from Repositories
# created: 2022-12-17 13:43:34
# date: 2026-04-13 23:15:28.510956
# authors:
#   - bendu
# label: delete-github-actions-secrets-from-repositories
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - GitHub
#   - REST
#   - RESTful
#   - API
#   - delete
#   - actions
#   - secrets
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import getpass
import requests

# %%
token = getpass.getpass()

# %%
resp = requests.get(
    url="https://api.github.com/orgs/legendu-net/repos?per_page=100",
    headers={
        "Accept": "application/vnd.github.v3+json",
        "Authorization": f"token {token}",
    },
)
resp
# Out:
# <Response [200]>

# %%
for repo in resp.json():
    repo = repo["name"]
    requests.delete(
        url=f"https://api.github.com/repos/legendu-net/{repo}/actions/secrets/GITHUBACTIONS",
        headers={"Authorization": f"token {token}"},
    )

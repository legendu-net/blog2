# %% [markdown]
# ---
# title: Transfer a Repository Using GitHub REST API
# date: 2022-12-17 13:47:30
# modified: 2026-01-01 17:36:43
# authors:
# - bendu
# label: transfer-a-repository-using-github-rest-api
# license: CC-BY-4.0
# tags:
# - Computer Science
# - programming
# - GitHub
# - REST
# - RESTful
# - API
# - transfer
# - repository
#
# ---
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
import getpass
import requests

# %%
token = getpass.getpass()

# %% [markdown]
# ## References
#
# https://docs.github.com/en/rest/repos/repos#transfer-a-repository

// %% [markdown]
// ---
// title: The Result Enum in Rust
// created: 2021-04-21 17:09:54
// date: 2026-04-13 23:15:28.855288
// authors:
//   - bendu
// label: the-result-enum-in-rust
// license: CC-BY-4.0
// tags:
//   - computer science
//   - programming
//   - Result
//   - Ok
//   - Err
//   - Rust
// ---
//
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %%
:timing
:sccache 1

// %% [markdown]
// ## References
//
// [Enum std::result::Result](https://doc.rust-lang.org/std/result/enum.Result.html)

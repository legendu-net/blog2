# %% [markdown]
# ---
# title: Tips on Omegaconf
# created: 2021-01-08 18:25:38
# date: 2026-04-13 23:15:28.888896
# authors:
#   - bendu
# label: tips-on-omegaconf
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - omegaconf
#   - Python
#   - config
#   - configuration
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %% [markdown]
#  ** Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement! **

# %% [markdown]
# 1. `omegaconf` can parse command-line options too.
# However,
# unlike `argparse` it does not enforce any constraint on command-line options.

# %% [markdown]
# ## References
#
# https://github.com/omry/omegaconf

# %% [markdown]
# ---
# title: Reshape Numpy Arrays
# created: 2021-10-07 13:08:24
# date: 2026-04-13 23:15:28.699700
# authors:
#   - bendu
# label: reshape-numpy-arrays
# license: CC-BY-4.0
# tags:
#   - computer science
#   - programming
#   - Python
#   - reshape
#   - stack
#   - repeat
# ---
#
# **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

# %%
reshape

# %%
stack

# %%
repeat

// %% [markdown]
// ---
// title: Hands on scala.math
// created: 2019-10-26
// date: 2019-10-26
// authors:
// - bendu
// label: hands-on-scala.math
// license: CC-BY-4.0
// tags:
// - programming
// - Scala
// - JVM
// - Java
// - math
// - scala.math
//
// ---
// **Things on this page are fragmentary and immature notes/thoughts of the author. Please read with your own judgement!**

// %% [markdown]
// http://www.scala-lang.org/api/2.12.3/scala/math/index.html

// %% [markdown]
// ## pow

// %% [markdown]
// ## ceil

// %% [markdown]
// ## floor

// %% [markdown]
// ## rint

// %% [markdown]
// ## sqrt
